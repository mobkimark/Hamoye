# %% [markdown]
# <a href="https://colab.research.google.com/github/mobkimark/Hamoye/blob/main/Quiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/FoodBalanceSheets_E_Africa_NOFLAG.csv", encoding = "latin-1")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
data.describe(include="all")
# Out:
#            Area Code   Area     Item Code                     Item  \
# count   60943.000000  60943  60943.000000                    60943
# unique           NaN     49           NaN                      119
# top              NaN  Kenya           NaN  Milk - Excluding Butter
# freq             NaN   1560           NaN                     1262
# mean      134.265576    NaN   2687.176706                      NaN
# std        72.605709    NaN    146.055739                      NaN
# min         4.000000    NaN   2501.000000                      NaN
# 25%        74.000000    NaN   2562.000000                      NaN
# 50%       136.000000    NaN   2630.000000                      NaN
# 75%       195.000000    NaN   2775.000000                      NaN
# max       276.000000    NaN   2961.000000                      NaN
#
#         Element Code                   Element         Unit          Y2014  \
# count   60943.000000                     60943        60943   59354.000000
# ...

# %%
data.isna().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
data.shape
# Out:
# (60943, 12)

# %%
data
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
data.corr()
# Out:
# <ipython-input-23-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# ...

# %%
group= data.groupby('Area')['Y2017'].sum().reset_index()

# %%
print(group)
# Out:
#                            Area       Y2017
# 0                       Algeria   325644.27
# 1                        Angola   229159.57
# 2                         Benin   124771.22
# 3                      Botswana    22101.30
# 4                  Burkina Faso   101855.07
# 5                    Cabo Verde    14650.74
# 6                      Cameroon   232030.43
# 7      Central African Republic    29937.00
# 8                          Chad    71594.68
# 9                       Comoros       59.84
# 10                        Congo    41181.68
# 11                Côte d'Ivoire   224599.01
# 12                     Djibouti    22729.91
# 13                        Egypt   866379.92
# 14                     Eswatini    54343.33
# 15                     Ethiopia   448683.76
# 16                 Ethiopia PDR        0.00
# 17                        Gabon    27979.64
# 18                       Gambia    23154.18
# 19                        Ghana   337599.06
# ...

# %%
maxnumber = group['Y2017'].max()
print(maxnumber)
# Out:
# 1483268.23

# %%
group1= data.groupby('Element')['Y2017'].sum().reset_index()
print(group1)
# Out:
#                                    Element       Y2017
# 0                 Domestic supply quantity  2088198.10
# 1                          Export Quantity   182338.80
# 2       Fat supply quantity (g/capita/day)    10253.84
# 3                                     Feed   223705.68
# 4                                     Food  1258888.28
# 5            Food supply (kcal/capita/day)   454681.00
# 6      Food supply quantity (kg/capita/yr)    48690.04
# 7                          Import Quantity   294559.09
# 8                                   Losses   160614.00
# 9                    Other uses (non-food)    91645.97
# 10                              Processing   292836.00
# 11                              Production  2030056.89
# 12  Protein supply quantity (g/capita/day)    11842.45
# 13                               Residuals    35500.00
# 14                                    Seed    24870.14
# 15                         Stock Variation    54316.91
# ...

# %%
data.shape
# Out:
# (60943, 12)

# %%
Mean_2017= data['Y2017'].mean()
SD_2017 = data ['Y2017']. std()
print(Mean_2017)
print(SD_2017)
# Out:
# 140.9177648602722
# 1671.8623590567995

# %%
group2= data.groupby('Item')['Y2015'].sum().reset_index()
print(group2)
# Out:
#                     Item      Y2015
# 0      Alcohol, Non-Food    2180.00
# 1    Alcoholic Beverages   98783.72
# 2        Animal Products   11811.73
# 3            Animal fats  200675.72
# 4    Apples and products   10559.15
# ..                   ...        ...
# 114    Vegetables, Other  158104.08
# 115     Vegetal Products  107064.17
# 116   Wheat and products  234710.51
# 117                 Wine    4251.81
# 118                 Yams  203151.78
#
# [119 rows x 2 columns]

# %%
group3= data.groupby('Element')['Y2014'].sum().reset_index()
group4= data.groupby('Element')['Y2015'].sum().reset_index()
group5= data.groupby('Element')['Y2016'].sum().reset_index()
group6= data.groupby('Element')['Y2017'].sum().reset_index()
group7= data.groupby('Element')['Y2018'].sum().reset_index()
print(group3)
print(group4)
print(group5)
print(group6)
print(group7)
# Out:
#                                    Element       Y2014
# 0                 Domestic supply quantity  1996716.35
# 1                          Export Quantity   150020.64
# 2       Fat supply quantity (g/capita/day)    10225.56
# 3                                     Feed   216927.89
# 4                                     Food  1212332.49
# 5            Food supply (kcal/capita/day)   454257.00
# 6      Food supply quantity (kg/capita/yr)    49650.63
# 7                          Import Quantity   274144.48
# 8                                   Losses   153223.00
# 9                    Other uses (non-food)    78718.13
# 10                              Processing   282923.00
# 11                              Production  1931287.75
# 12  Protein supply quantity (g/capita/day)    11836.46
# 13                               Residuals    30149.00
# 14                                    Seed    21922.92
# 15                         Stock Variation    58749.83
# ...

# %%
S = [['him','sell'],[90,28,43]]
S[0][1][1]
# Out:
# 'e'
